# %% [markdown]
# # 21 — Load Clean Data for EDA
#
# ## Goal
# To load the cleaned MotionSense-AI dataset and prepare for exploratory data analysis.
#
# ## MotionSense-AI connection
# Here, we use statistics and visualizations to understand the cleaned smartphone sensor dataset before building a machine learning model.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

DATA_DIR = Path("../data")
RAW_PATH = DATA_DIR / "raw" / "motionsense_raw.csv"
CLEAN_PATH = DATA_DIR / "processed" / "motionsense_clean.csv"
ML_READY_PATH = DATA_DIR / "processed" / "motionsense_ml_ready.csv"
FIGURE_DIR = Path("figures")
FIGURE_DIR.mkdir(exist_ok=True)

pd.set_option("display.max_columns", 20)
pd.set_option("display.width", 120)

# %% [markdown]
# ## Why this matters
# Before building charts or calculating statistics, we need to load the cleaned dataset.
#
# EDA means **Exploratory Data Analysis**. It helps us understand the dataset before training a model.

# %%
# Load the cleaned dataset.
df = pd.read_csv(CLEAN_PATH)

# Display the number of rows and columns.
print("Clean dataset shape:", df.shape)

# Preview the first five rows.
df.head()
# Out:
# Clean dataset shape: (1320, 13)
#    row_id  subject  time_step activity     acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z   device  \
# 0       1        3          0  Walking -0.190664  0.687583  1.129328  0.005386 -0.143240  0.014062  phone_A
# 1       2       24          1  Walking  0.010593  0.542629  0.998704  0.316734  0.085557  0.007263  phone_B
# 2       3       13          2  Walking  0.221782  0.375365  1.277480  0.114523  0.096630 -0.005492  phone_A
# 3       4       25          3  Walking  0.167558  0.386942  1.495453  0.203002 -0.047116 -0.038735  phone_A
# 4       5       11          4  Walking  0.330682  0.558338  1.472442  0.455581 -0.044706 -0.056347  phone_A
#
#    acc_magnitude  gyro_magnitude
# 0       1.335853        0.144029
# 1       1.136647        0.328166
# 2       1.349830        0.149943
# 3       1.553763        0.211967
# 4       1.609092        0.461224

# %%
# Check the column names.
# These are the features we can analyze and visualize.
print(df.columns.tolist())
# Out:
# ['row_id', 'subject', 'time_step', 'activity', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'device', 'acc_magnitude', 'gyro_magnitude']

# %%
# Check the data types.
# Numeric columns can be summarized and plotted as measurements.
df.dtypes
# Out:
# row_id              int64
# subject             int64
# time_step           int64
# activity              str
# acc_x             float64
# acc_y             float64
# acc_z             float64
# gyro_x            float64
# gyro_y            float64
# gyro_z            float64
# device                str
# acc_magnitude     float64
# gyro_magnitude    float64
# dtype: object

# %% [markdown]
# ## Summary
# We loaded the cleaned dataset and confirmed which numeric columns are available and can be used for analysis.
