# %% [markdown]
# # 06 — Select Columns and Rows
#
# **Goal:** To select only the data needed for analysis.

# %%
from pathlib import Path
import numpy as np
import pandas as pd

DATA_PATH = Path('../data/raw/motionsense_raw.csv')

# Load the raw MotionSense-style sensor dataset.
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    row_id  subject  time_step activity     acc_x     acc_y     acc_z  \
# 0       1        3          0  Walking -0.190664  0.687583  1.129328
# 1       2       24          1  Walking  0.010593  0.542629  0.998704
# 2       3       13          2  Walking  0.221782  0.375365  1.277480
# 3       4       25          3  Walking  0.167558  0.386942  1.495453
# 4       5       11          4  Walking  0.330682  0.558338  1.472442
#
#      gyro_x    gyro_y    gyro_z   device
# 0  0.005386 -0.143240  0.014062  phone_A
# 1  0.316734  0.085557  0.007263  phone_B
# 2  0.114523  0.096630 -0.005492  phone_A
# 3  0.203002 -0.047116 -0.038735  phone_A
# 4  0.455581 -0.044706 -0.056347  phone_A

# %%
# Select one column.
# This returns a Pandas Series.
activity_column = df['activity']
activity_column.head()
# Out:
# 0    Walking
# 1    Walking
# 2    Walking
# 3    Walking
# 4    Walking
# Name: activity, dtype: str

# %%
# Select multiple columns.
# Use a list of column names inside df[...].
sensor_columns = ['activity', 'acc_x', 'acc_y', 'acc_z']
df[sensor_columns].head()
# Out:
#   activity     acc_x     acc_y     acc_z
# 0  Walking -0.190664  0.687583  1.129328
# 1  Walking  0.010593  0.542629  0.998704
# 2  Walking  0.221782  0.375365  1.277480
# 3  Walking  0.167558  0.386942  1.495453
# 4  Walking  0.330682  0.558338  1.472442

# %%
# iloc selects rows and columns by position.
# This selects the first row.
df.iloc[0]
# Out:
# row_id              1
# subject             3
# time_step           0
# activity      Walking
# acc_x       -0.190664
# acc_y        0.687583
# acc_z        1.129328
# gyro_x       0.005386
# gyro_y       -0.14324
# gyro_z       0.014062
# device        phone_A
# Name: 0, dtype: object

# %%
# This selects the first 5 rows and first 4 columns.
# Rows: :5 means positions 0, 1, 2, 3, 4.
# Columns: :4 means positions 0, 1, 2, 3.
df.iloc[:5, :4]
# Out:
#    row_id  subject  time_step activity
# 0       1        3          0  Walking
# 1       2       24          1  Walking
# 2       3       13          2  Walking
# 3       4       25          3  Walking
# 4       5       11          4  Walking

# %% [markdown]
# ## Summary
#
# - Use `df['column']` for one column.
# - Use `df[[...]]` for multiple columns.
# - Use `iloc` when selecting by position.
