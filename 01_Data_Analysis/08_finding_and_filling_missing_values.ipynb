# %% [markdown]
# # 08 — Finding & Filling Missing Values
#
# **Goal:** To find missing values and handle them safely.

# %%
from pathlib import Path
import numpy as np
import pandas as pd

DATA_PATH = Path('../data/raw/motionsense_raw.csv')

# Load the raw MotionSense-style sensor dataset.
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    row_id  subject  time_step activity     acc_x     acc_y     acc_z  \
# 0       1        3          0  Walking -0.190664  0.687583  1.129328
# 1       2       24          1  Walking  0.010593  0.542629  0.998704
# 2       3       13          2  Walking  0.221782  0.375365  1.277480
# 3       4       25          3  Walking  0.167558  0.386942  1.495453
# 4       5       11          4  Walking  0.330682  0.558338  1.472442
#
#      gyro_x    gyro_y    gyro_z   device
# 0  0.005386 -0.143240  0.014062  phone_A
# 1  0.316734  0.085557  0.007263  phone_B
# 2  0.114523  0.096630 -0.005492  phone_A
# 3  0.203002 -0.047116 -0.038735  phone_A
# 4  0.455581 -0.044706 -0.056347  phone_A

# %%
# Count missing values in each column.
# Columns with 0 have no missing values.
missing_counts = df.isnull().sum()
print(missing_counts)
missing_counts[missing_counts > 0]
# Out:
# row_id       0
# subject      0
# time_step    0
# activity     0
# acc_x        5
# acc_y        5
# acc_z        0
# gyro_x       0
# gyro_y       0
# gyro_z       5
# device       0
# dtype: int64
# acc_x     5
# acc_y     5
# gyro_z    5
# dtype: int64

# %%
# Show rows where at least one value is missing.
# any(axis=1) checks across each row.
rows_with_missing = df[df.isnull().any(axis=1)]
rows_with_missing
df.isnull().sum()
# Out:
# row_id       0
# subject      0
# time_step    0
# activity     0
# acc_x        5
# acc_y        5
# acc_z        0
# gyro_x       0
# gyro_y       0
# gyro_z       5
# device       0
# dtype: int64

# %%
# Create a copy before cleaning.
# This keeps the original raw DataFrame unchanged.
clean_df = df.copy()

# Fill missing sensor values using the column mean.
# This is a simple beginner-friendly cleaning strategy.
sensor_cols = ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']
for col in sensor_cols:
    clean_df[col] = clean_df[col].fillna(clean_df[col].mean())

# Verify that missing sensor values are gone.
clean_df[sensor_cols].isnull().sum()
# Out:
# acc_x     0
# acc_y     0
# acc_z     0
# gyro_x    0
# gyro_y    0
# gyro_z    0
# dtype: int64

# %% [markdown]
# ## Summary
#
# Real datasets can contain missing values.
#
# A simple workflow is:
#
# 1. Count missing values.
# 2. Inspect rows with missing values.
# 3. Fill or remove missing values.
