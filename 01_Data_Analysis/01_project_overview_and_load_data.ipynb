# %% [markdown]
# # 01 — MotionSense-AI Project Overview and Load Data
#
# This notebook introduces the shared dataset used across the entire project.
#
# **Goal:** To understand the project question and load the raw data.

# %% [markdown]
# ## Project Question
#
# Can smartphone sensor readings help identify a person's activity?
#
# In this dataset:
#
# - Each **row** is one sensor observation.
# - Each **column** is a data field.
# - Sensor columns such as `acc_x`, `acc_y`, and `acc_z` are **features**.
# - `activity` is the **target** we eventually want to predict.

# %%
from pathlib import Path
import pandas as pd

# All notebooks use the same raw dataset.
# The notebook is inside 01_Data_Analysis, so '../data/raw/...' moves one folder up.
DATA_PATH = Path('../data/raw/motionsense_raw.csv')

# Load the raw MotionSense-style sensor dataset.
df = pd.read_csv(DATA_PATH)

# Display the first five rows.
# This gives a quick preview of the table structure.
df.head()
# df.head(10)    # First 10 rows

# df.tail()     # Last 3 rows
# df.tail(3)     # Last 3 rows

# df.info()      # Summary of dataframe
# df.describe()  # Statistics
# df.shape       # (rows, columns)
# df.columns     # Column names
# df.index       # Row numbers
# df.dtypes      # Data types

# df.sample(5)
# Out:
#    row_id  subject  time_step activity     acc_x     acc_y     acc_z  \
# 0       1        3          0  Walking -0.190664  0.687583  1.129328
# 1       2       24          1  Walking  0.010593  0.542629  0.998704
# 2       3       13          2  Walking  0.221782  0.375365  1.277480
# 3       4       25          3  Walking  0.167558  0.386942  1.495453
# 4       5       11          4  Walking  0.330682  0.558338  1.472442
#
#      gyro_x    gyro_y    gyro_z   device
# 0  0.005386 -0.143240  0.014062  phone_A
# 1  0.316734  0.085557  0.007263  phone_B
# 2  0.114523  0.096630 -0.005492  phone_A
# 3  0.203002 -0.047116 -0.038735  phone_A
# 4  0.455581 -0.044706 -0.056347  phone_A

# %%
# Display the number of rows and columns.
print('Rows and columns:', df.shape)

# Display the column names as a simple Python list.
print('Columns:')
print(df.columns.tolist())
# df.isna().sum()
# Out:
# Rows and columns: (1320, 11)
# Columns:
# ['row_id', 'subject', 'time_step', 'activity', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'device']

# %% [markdown]
# ## Quick Check
#
# The dataset is now loaded into a DataFrame named `df`.
#
# Key idea: **Data comes before AI.** Before modeling, we first inspect and understand the data.
